# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1064a4d1-6eb9-4007-b988-54107cdc19d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1064a4d1-6eb9-4007-b988-54107cdc19d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train.csv

# %%
training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 2s 2ms/step - loss: 0.3930
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3023
# Epoch 3/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2328
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1814
# Epoch 5/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1442
# Epoch 6/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1185
# Epoch 7/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1018
# Epoch 8/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0914
# Epoch 9/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 10/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0819
# Epoch 11/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0798
# Epoch 12/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 13/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0773
# Epoch 14/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0764
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0755
# Epoch 16/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0746
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0738
# Epoch 18/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0729
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0719
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0711
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0692
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0682
# Epoch 24/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0672
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0662
# Epoch 26/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0652
# Epoch 27/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0642
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0620
# Epoch 30/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0608
# Epoch 31/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0596
# Epoch 32/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0584
# Epoch 33/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 34/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0559
# Epoch 35/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0546
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0533
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 38/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0505
# Epoch 39/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0490
# Epoch 40/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0474
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0459
# Epoch 42/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0443
# Epoch 43/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0427
# Epoch 44/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0410
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 46/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0377
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0323
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0305
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0288
# Epoch 52/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0218
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0202
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 61/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 62/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 63/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 64/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 66/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 67/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 69/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 70/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 71/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 73/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 74/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 75/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 77/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 78/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 79/200
# 40/40 [==============================] - 0s 7ms/step - loss: 9.4112e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 8ms/step - loss: 8.0515e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 7ms/step - loss: 6.9395e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 6ms/step - loss: 6.0491e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 6ms/step - loss: 5.3145e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 9ms/step - loss: 4.7416e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.2779e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.9212e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.6313e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 6ms/step - loss: 3.4128e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 7ms/step - loss: 3.2502e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 5ms/step - loss: 3.1140e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 5ms/step - loss: 3.0174e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.9440e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8899e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8535e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 7ms/step - loss: 2.8342e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8030e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7823e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7723e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7654e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7612e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7581e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.7505e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7508e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7483e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7441e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7461e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.7435e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7505e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7405e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7445e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7384e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7453e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7390e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7548e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7380e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.7483e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7425e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7402e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7368e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7398e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7328e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7339e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7399e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7321e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7340e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7346e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7377e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7462e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7279e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7386e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7255e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7334e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7317e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7309e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7202e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7389e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7247e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7366e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7560e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7325e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7512e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7218e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7306e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7293e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7713e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7243e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7289e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7228e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7235e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7378e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7437e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7293e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7264e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7432e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7167e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7221e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7460e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7292e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7158e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7314e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7390e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7393e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7365e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7187e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7192e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7287e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7389e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7379e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7155e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7249e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7444e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7652e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7189e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7182e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7247e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7218e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7245e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7270e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7471e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7382e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7225e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7310e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7026e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7673e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7379e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7312e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7105e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7104e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7196e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7087e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7374e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7246e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7179e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7204e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7299e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7119e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7037e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7268e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7430e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7142e-04

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7240bae6-fbc3-4991-ba93-38f2f34eda98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7240bae6-fbc3-4991-ba93-38f2f34eda98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test.csv

# %%
# getting the real stock of 2017 i.e., importing the test dataset

test_data = pd.read_csv('/content/Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[774.6355 ],
#        [782.67914],
#        [780.77057],
#        [788.41003],
#        [797.51764],
#        [798.69794],
#        [796.38293],
#        [798.1162 ],
#        [798.39105],
#        [798.06775],
#        [797.0398 ],
#        [796.48035],
#        [797.93024],
#        [798.20514],
#        [810.2038 ],
#        [815.91925],
#        [822.2202 ],
#        [819.847  ],
#        [804.15424],
#        [789.7291 ]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# Evaluating the RNN model

import math

from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))

print(rmse)
